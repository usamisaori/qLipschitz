# %%
import pennylane as qml
import numpy as np
from pennylane.optimize import AdamOptimizer
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1 prepare data

# %%
def loadData(filename):
    return_data = []
    return_label = []
    
    with open(filename, 'r') as file:
        for row in file:
            data = row.split(' ')[:-1]
            data = [ float(d) for d in data ]
            
            label = int(row.split(' ')[-1])
            
            return_data.append(data)
            return_label.append(label)
    
    return np.array(return_data), np.array(return_label)

# %% [markdown]
# ### - 1.1 Plot origin data

# %%
X_train, Y_train = loadData('./data/training_set.txt')
X_test, Y_test = loadData('./data/testing_set.txt')

print(X_train[:10])
print(Y_train[:10])
# Out:
# [[-0.2267158   0.05544076]
#  [ 0.50765298 -0.05327558]
#  [ 0.47825277  0.8397753 ]
#  [ 0.16357475 -1.13609656]
#  [-0.15782768  0.33956209]
#  [ 0.30480062 -0.23580736]
#  [-0.39587536 -0.00892146]
#  [-0.37899817  0.90050109]
#  [ 0.28139666 -0.87140533]
#  [-1.06543637 -0.25802502]]
# [1 1 0 0 1 1 1 0 0 0]

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=Y_train)
plt.show()

# %%
print(f'total datas: {len(X_train)}')
print(f'label 0 datas: {len(list(filter(lambda x: x==0, Y_train)))}')
print(f'label 0 datas: {len(list(filter(lambda x: x==1, Y_train)))}')
# Out:
# total datas: 40
# label 0 datas: 20
# label 0 datas: 20

# %% [markdown]
# ### - 1.2 add rotated datas

# %%
def rotateDatas(X, Y):
    gen_X = []
    gen_Y = []
    
    for i, data in enumerate(X):
        gen_X.append(list(reversed(data)))
        gen_Y.append(Y[i])
    
    return np.array(gen_X), np.array(gen_Y)

# %%
X_train_rotate, Y_train_rotate = rotateDatas(X_train, Y_train)

# %%
plt.scatter(X_train_rotate[:, 0], X_train_rotate[:, 1], c=Y_train_rotate)
plt.show()

# %%
# Concat datas

X_temp = np.zeros((X_train.shape[0] * 2, len(X_train[0])))
X_temp[0:40,:] = X_train
X_temp[40:80,] = X_train_rotate
Y_temp = np.zeros((Y_train.shape[0] * 2))
Y_temp[0:40] = Y_train
Y_temp[40:80] = Y_train_rotate

plt.scatter(X_temp[:, 0], X_temp[:, 1], c=Y_temp)
plt.show()

X_train = X_temp
Y_train = Y_temp

# %%
print(f'total datas: {len(X_train)}')
print(f'label 0 datas: {len(list(filter(lambda x: x==0, Y_train)))}')
print(f'label 0 datas: {len(list(filter(lambda x: x==1, Y_train)))}')
# Out:
# total datas: 80
# label 0 datas: 40
# label 0 datas: 40

# %% [markdown]
# ### - 1.3 add new dimention datas

# %%
Z_train = (X_train[:, 0] ** 2 + X_train[:, 1] ** 2) ** 0.5
# Z_train = (X_train[:, 0] ** 2 + X_train[:, 1] ** 2)
temp = np.zeros((X_train.shape[0], len(X_train[0]) + 1))
temp[:, :-1] = X_train
temp[:, -1] = Z_train
X_train2 = temp

print(X_train2[:10])

Z_test = (X_test[:, 0] ** 2 + X_test[:, 1] ** 2) ** 0.5
# Z_test = (X_test[:, 0] ** 2 + X_test[:, 1] ** 2)
temp = np.zeros((X_test.shape[0], len(X_test[0]) + 1))
temp[:, :-1] = X_test
temp[:, -1] = Z_test
X_test2 = temp

print(X_test2[:10])
# Out:
# [[-0.2267158   0.05544076  0.23339609]
#  [ 0.50765298 -0.05327558  0.51044082]
#  [ 0.47825277  0.8397753   0.96640999]
#  [ 0.16357475 -1.13609656  1.14781187]
#  [-0.15782768  0.33956209  0.37444891]
#  [ 0.30480062 -0.23580736  0.38536805]
#  [-0.39587536 -0.00892146  0.39597587]
#  [-0.37899817  0.90050109  0.97700656]
#  [ 0.28139666 -0.87140533  0.91571356]
#  [-1.06543637 -0.25802502  1.09623518]]
# [[ 0.68895797  0.51869417  0.86238433]
#  [ 0.8945632  -0.10088915  0.90023438]
#  [ 0.90679326 -0.41487915  0.99719543]
#  [-0.5254954  -0.61240277  0.80695884]
#  [-0.17215401  0.1029693   0.20059831]
#  [-0.15184262  0.32639704  0.35998779]
#  [-0.3459131  -0.28434657  0.44778214]
#  [-0.69543711  0.6475674   0.95025066]
#  [ 0.41855711  1.10908408  1.18543559]
#  [-0.1401844   0.25001559  0.28663472]]

# %%
def plot3D(X, Y):
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(
        X[:, 0], X[:, 1], X[:, 2], 
        zdir='z', s=30, c=Y, depthshade=True
    )
    plt.show()

# %%
plot3D(X_train2, Y_train)

# %%
print(f'total datas: {len(X_train2)}')
print(f'label 0 datas: {len(list(filter(lambda x: x==0, Y_train)))}')
print(f'label 0 datas: {len(list(filter(lambda x: x==1, Y_train)))}')
# Out:
# total datas: 80
# label 0 datas: 40
# label 0 datas: 40

# %% [markdown]
# ## Step 2 train model

# %%
qubits_num = 3
layers_num = 2

dev = qml.device("default.qubit",wires=qubits_num)

# %% [markdown]
# ### - 2.0 Classifier

# %%
class VQC:
    def __init__(self):
        # 3 => U3(theta, phi, lambda)
        self.params = (0.01 * np.random.randn(layers_num, qubits_num, 3))
        self.bestparams = self.params
        self.bestcost = 10
        
        self.opt = AdamOptimizer(0.205)
        
        self.weights = []
        self.costs = []
        self.accuracies = []
        
    def fit(self, X_train, Y_train, epoch=300):
        batch_size = 20

        for turn in range(epoch):
            # Update the weights by one optimizer step
            batch_index = np.random.randint(0, len(X_train), (batch_size,))
            X_train_batch = X_train[batch_index]
            Y_train_batch = Y_train[batch_index]
            self.params = self.opt.step(lambda v: cost(v, X_train_batch, Y_train_batch), self.params)

            cost_now = cost(self.params, X_train, Y_train)
            acc_now = accuracy(self.params, X_train, Y_train) 

            if cost_now < self.bestcost:
                self.bestcost = cost_now
                self.bestparams = self.params
            
            self.weights.append(self.params)
            self.costs.append(cost_now)
            self.accuracies.append(acc_now)
            
            print(
                "Turn: {:5d} | Cost: {:0.7f} | Accuracy: {:0.2f}% ".format(
                turn + 1, cost_now, acc_now * 100
            ))
            
    def score(self, X_test, Y_test):
        predictions = [ predict(self.bestparams, data) for data in X_test ]
        acc = accuracy(self.bestparams, X_test, Y_test)
        
        print("FINAL ACCURACY: {:0.2f}%".format(acc * 100))

# %% [markdown]
# ### - 2.1 Circuit object

# %%
@qml.qnode(dev)
def circuit(params, data):
    angles = [ i  * np.pi for i in data ]

    for i in range(qubits_num):
        qml.RX(angles[i], wires=i)
        qml.Rot( *params[0, i], wires=i )

    qml.CZ(wires=[1, 0])
    qml.CZ(wires=[1, 2])
    qml.CZ(wires=[0, 2])

    for i in range(qubits_num):
        qml.Rot( *params[1, i], wires=i )
    
    # PauliZ measure => 1 -> |0>  while -1 -> |1>
    return qml.expval(qml.PauliZ(0)), qml.expval(qml.PauliZ(1)), qml.expval(qml.PauliZ(2))

# %% [markdown]
# ### - 2.2 Prediction

# %%
import qiskit
import numpy as np
from qiskit import QuantumCircuit
from qiskit import Aer, execute

unitary_backend = Aer.get_backend('unitary_simulator')
qasm_backend = Aer.get_backend('qasm_simulator')

# %%
def predict(params, data):
    qcircuit = QuantumCircuit(3, 3)
    qubits = qcircuit.qubits

    for i, d in enumerate(data):
        qcircuit.rx(d * np.pi, qubits[i])
        
    for i in range(qubits_num):
        qcircuit.u3(*params[0][i], qubits[i])

    qcircuit.cz(qubits[0], qubits[1])
    qcircuit.cz(qubits[1], qubits[2])
    qcircuit.cz(qubits[0], qubits[2])

    for i in range(qubits_num):
        qcircuit.u3(*params[1][i], qubits[i])
    
    # the measurement
    qcircuit.measure([0, 1, 2], [0, 1, 2])

    # job execution
    shots = 1000
    job_sim = execute(qcircuit, qasm_backend, shots=shots)
    result_sim = job_sim.result()
    counts = result_sim.get_counts(qcircuit)

    p1 = (counts.get('100', 0) + counts.get('111', 0) + counts.get('101', 0) + counts.get('110',0)) / shots
    
    if p1 > 0.5:
        return 1
    else:
        return 0

# %% [markdown]
# ### - 2.3 Loss and accuracy

# %%
def cost(weights, datas, labels):
    loss = 0
    
    for i, data in enumerate(datas):
        # like [-1, 1, 1]
        measured = circuit(weights, data)

        p = measured[2]
        if labels[i] == 0:
            loss += (1 - p) ** 2
        else:
            loss += (-1 - p) ** 2
            
        
    return loss / len(datas)

# %%
def accuracy(weights, datas, labels):
    predictions = [ predict(weights, data) for data in datas ]
    
    acc = 0
    for i, p in enumerate(predictions):
        if p == labels[i]:
            acc += 1
    
    return acc / len(predictions)

# %% [markdown]
# ### - 2.4 Train model

# %%
vqc = VQC()
vqc.fit(X_train2, Y_train, epoch=200)
# Out:
# C:\Users\lenovo\AppData\Local\Temp/ipykernel_6508/1801830318.py:9: DeprecationWarning: The QuantumCircuit.u3 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use QuantumCircuit.u instead, which acts identically. Alternatively, you can decompose u3 in terms of QuantumCircuit.p and QuantumCircuit.sx: u3(ϴ,φ,λ) = p(φ+π) sx p(ϴ+π) sx p(λ) (2 pulses on hardware).
#   qcircuit.u3(*params[0][i], qubits[i])
# C:\Users\lenovo\AppData\Local\Temp/ipykernel_6508/1801830318.py:16: DeprecationWarning: The QuantumCircuit.u3 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use QuantumCircuit.u instead, which acts identically. Alternatively, you can decompose u3 in terms of QuantumCircuit.p and QuantumCircuit.sx: u3(ϴ,φ,λ) = p(φ+π) sx p(ϴ+π) sx p(λ) (2 pulses on hardware).
#   qcircuit.u3(*params[1][i], qubits[i])
# Turn:     1 | Cost: 2.9936859 | Accuracy: 2.50%
# Turn:     2 | Cost: 2.6881203 | Accuracy: 5.00%
# Turn:     3 | Cost: 2.2275503 | Accuracy: 3.75%
# Turn:     4 | Cost: 1.7168380 | Accuracy: 3.75%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6508/955686683.py in <module>
#       1 vqc = VQC()
# ----> 2 vqc.fit(X_train2, Y_train, epoch=200)
#
# ~\AppData\Local\Temp/ipykernel_6508/2556874709.py in fit(self, X_train, Y_train, epoch)
#      23
#      24             cost_now = cost(self.params, X_train, Y_train)
# ---> 25             acc_now = accuracy(self.params, X_train, Y_train)
#      26
#      27             if cost_now < self.bestcost:
#
# ~\AppData\Local\Temp/ipykernel_6508/26158528.py in accuracy(weights, datas, labels)
#       1 def accuracy(weights, datas, labels):
# ----> 2     predictions = [ predict(weights, data) for data in datas ]
#       3
#       4     acc = 0
#       5     for i, p in enumerate(predictions):
#
# ~\AppData\Local\Temp/ipykernel_6508/26158528.py in <listcomp>(.0)
#       1 def accuracy(weights, datas, labels):
# ----> 2     predictions = [ predict(weights, data) for data in datas ]
#       3
#       4     acc = 0
#       5     for i, p in enumerate(predictions):
#
# ~\AppData\Local\Temp/ipykernel_6508/1801830318.py in predict(params, data)
#      21     # job execution
#      22     shots = 1000
# ---> 23     job_sim = execute(qcircuit, qasm_backend, shots=shots)
#      24     result_sim = job_sim.result()
#      25     counts = result_sim.get_counts(qcircuit)
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\execute_function.py in execute(experiments, backend, basis_gates, coupling_map, backend_properties, initial_layout, seed_transpiler, optimization_level, pass_manager, qobj_id, qobj_header, shots, memory, max_credits, seed_simulator, default_qubit_los, default_meas_los, qubit_lo_range, meas_lo_range, schedule_los, meas_level, meas_return, memory_slots, memory_slot_size, rep_time, rep_delay, parameter_binds, schedule_circuit, inst_map, meas_map, scheduling_method, init_qubits, **run_config)
#     292     else:
#     293         # transpiling the circuits using given transpile options
# --> 294         experiments = transpile(
#     295             experiments,
#     296             basis_gates=basis_gates,
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\compiler\transpiler.py in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, pass_manager, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target)
#     333
#     334     # Transpile circuits in parallel
# --> 335     circuits = parallel_map(_transpile_circuit, list(zip(circuits, transpile_args)))
#     336
#     337     end_time = time()
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\tools\parallel.py in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     130         return []
#     131     if len(values) == 1:
# --> 132         return [task(values[0], *task_args, **task_kwargs)]
#     133
#     134     Publisher().publish("terra.parallel.start", len(values))
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\compiler\transpiler.py in _transpile_circuit(circuit_config_tuple)
#     427         raise TranspilerError("optimization_level can range from 0 to 3.")
#     428
# --> 429     result = pass_manager.run(
#     430         circuit, callback=transpile_config["callback"], output_name=transpile_config["output_name"]
#     431     )
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\transpiler\passmanager.py in run(self, circuits, output_name, callback)
#     216             return circuits
#     217         if isinstance(circuits, QuantumCircuit):
# --> 218             return self._run_single_circuit(circuits, output_name, callback)
#     219         if len(circuits) == 1:
#     220             return self._run_single_circuit(circuits[0], output_name, callback)
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\transpiler\passmanager.py in _run_single_circuit(self, circuit, output_name, callback)
#     271         """
#     272         running_passmanager = self._create_running_passmanager()
# --> 273         result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     274         self.property_set = running_passmanager.property_set
#     275         return result
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\transpiler\runningpassmanager.py in run(***failed resolving arguments***)
#     121         for passset in self.working_list:
#     122             for pass_ in passset:
# --> 123                 dag = self._do_pass(pass_, dag, passset.options)
#     124
#     125         circuit = dag_to_circuit(dag)
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\transpiler\runningpassmanager.py in _do_pass(self, pass_, dag, options)
#     152         # Run the pass itself, if not already run
#     153         if pass_ not in self.valid_passes:
# --> 154             dag = self._run_this_pass(pass_, dag)
#     155
#     156             # update the valid_passes property
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\transpiler\runningpassmanager.py in _run_this_pass(self, pass_, dag)
#     164             # Measure time if we have a callback or logging set
#     165             start_time = time()
# --> 166             new_dag = pass_.run(dag)
#     167             end_time = time()
#     168             run_time = end_time - start_time
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\transpiler\passes\optimization\optimize_1q_decomposition.py in run(self, dag)
#     166                     continue
#     167
# --> 168             new_basis, new_circ = self._resynthesize_run(run)
#     169
#     170             if new_circ is not None and self._substitution_checks(dag, run, new_circ, new_basis):
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\transpiler\passes\optimization\optimize_1q_decomposition.py in _resynthesize_run(self, run)
#      76             operator = gate.op.to_matrix().dot(operator)
#      77
# ---> 78         new_circs = {k: v._decompose(operator) for k, v in self._decomposers.items()}
#      79
#      80         new_basis, new_circ = None, None
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\transpiler\passes\optimization\optimize_1q_decomposition.py in <dictcomp>(.0)
#      76             operator = gate.op.to_matrix().dot(operator)
#      77
# ---> 78         new_circs = {k: v._decompose(operator) for k, v in self._decomposers.items()}
#      79
#      80         new_basis, new_circ = None, None
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\quantum_info\synthesis\one_qubit_decompose.py in _decompose(self, unitary, simplify, atol)
#     165
#     166     def _decompose(self, unitary, simplify=True, atol=DEFAULT_ATOL):
# --> 167         theta, phi, lam, phase = self._params(unitary)
#     168         circuit = self._circuit(theta, phi, lam, phase, simplify=simplify, atol=atol)
#     169         return circuit
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\quantum_info\synthesis\one_qubit_decompose.py in _params_u1x(mat)
#     292         # Since the phase is wrt to a SU matrix we must rescale
#     293         # phase to correct this
# --> 294         theta, phi, lam, phase = OneQubitEulerDecomposer._params_zyz(mat)
#     295         return theta, phi, lam, phase - 0.5 * (theta + phi + lam)
#     296
#
# ~\anaconda3\envs\py38\lib\site-packages\qiskit\quantum_info\synthesis\one_qubit_decompose.py in _params_zyz(mat)
#     224         # We rescale the input matrix to be special unitary (det(U) = 1)
#     225         # This ensures that the quaternion representation is real
# --> 226         coeff = la.det(mat) ** (-0.5)
#     227         phase = -cmath.phase(coeff)
#     228         su_mat = coeff * mat  # U in SU(2)
#
# ~\anaconda3\envs\py38\lib\site-packages\scipy\linalg\basic.py in det(a, overwrite_a, check_finite)
#    1026     overwrite_a = overwrite_a or _datacopied(a1, a)
#    1027     fdet, = get_flinalg_funcs(('det',), (a1,))
# -> 1028     a_det, info = fdet(a1, overwrite_a=overwrite_a)
#    1029     if info < 0:
#    1030         raise ValueError('illegal value in %d-th argument of internal '
#
# KeyboardInterrupt:
